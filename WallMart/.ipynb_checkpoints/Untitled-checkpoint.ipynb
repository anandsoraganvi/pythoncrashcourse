# %%
# data analysis
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()
train_df = pd.read_csv('train.csv')
weather_df = pd.read_csv('weather.csv')
key_df = pd.read_csv('key.csv')
print(train_df.head())
# Out:
#          date  store_nbr  item_nbr  units
# 0  2012-01-01          1         1      0
# 1  2012-01-01          1         2      0
# 2  2012-01-01          1         3      0
# 3  2012-01-01          1         4      0
# 4  2012-01-01          1         5      0

# %%
comb_1_df = pd.merge(key_df, weather_df, on='station_nbr')
comb_2_df = pd.merge(train_df, comb_1_df, on=['store_nbr', 'date'])

# %%
few_comb2_df =comb_2_df.head(10000)
few_comb2_df.head(10)
# Out:
#          date  store_nbr  item_nbr  units  station_nbr tmax tmin tavg depart  \
# 0  2012-01-01          1         1      0            1   52   31   42      M
# 1  2012-01-01          1         2      0            1   52   31   42      M
# 2  2012-01-01          1         3      0            1   52   31   42      M
# 3  2012-01-01          1         4      0            1   52   31   42      M
# 4  2012-01-01          1         5      0            1   52   31   42      M
# 5  2012-01-01          1         6      0            1   52   31   42      M
# 6  2012-01-01          1         7      0            1   52   31   42      M
# 7  2012-01-01          1         8      0            1   52   31   42      M
# 8  2012-01-01          1         9     29            1   52   31   42      M
# 9  2012-01-01          1        10      0            1   52   31   42      M
#
#   dewpoint   ...    sunrise sunset     codesum snowfall preciptotal  \
# 0       36   ...          -      -  RA FZFG BR        M        0.05
# 1       36   ...          -      -  RA FZFG BR        M        0.05
# 2       36   ...          -      -  RA FZFG BR        M        0.05
# 3       36   ...          -      -  RA FZFG BR        M        0.05
# 4       36   ...          -      -  RA FZFG BR        M        0.05
# 5       36   ...          -      -  RA FZFG BR        M        0.05
# 6       36   ...          -      -  RA FZFG BR        M        0.05
# 7       36   ...          -      -  RA FZFG BR        M        0.05
# 8       36   ...          -      -  RA FZFG BR        M        0.05
# 9       36   ...          -      -  RA FZFG BR        M        0.05
#
#   stnpressure sealevel resultspeed resultdir avgspeed
# 0       29.78    29.92         3.6        20      4.6
# 1       29.78    29.92         3.6        20      4.6
# 2       29.78    29.92         3.6        20      4.6
# 3       29.78    29.92         3.6        20      4.6
# 4       29.78    29.92         3.6        20      4.6
# 5       29.78    29.92         3.6        20      4.6
# 6       29.78    29.92         3.6        20      4.6
# 7       29.78    29.92         3.6        20      4.6
# 8       29.78    29.92         3.6        20      4.6
# 9       29.78    29.92         3.6        20      4.6
#
# [10 rows x 23 columns]

# %%
few_comb2_df_tmax=few_comb2_df[few_comb2_df['tmax']=='M']
few_comb2_df_tmax
# Out:
# Empty DataFrame
# Columns: [date, store_nbr, item_nbr, units, station_nbr, tmax, tmin, tavg, depart, dewpoint, wetbulb, heat, cool, sunrise, sunset, codesum, snowfall, preciptotal, stnpressure, sealevel, resultspeed, resultdir, avgspeed]
# Index: []
#
# [0 rows x 23 columns]

# %%
few_comb2_df_tmin=few_comb2_df[few_comb2_df['tmin']=='M']
few_comb2_df_tmin
# Out:
# Empty DataFrame
# Columns: [date, store_nbr, item_nbr, units, station_nbr, tmax, tmin, tavg, depart, dewpoint, wetbulb, heat, cool, sunrise, sunset, codesum, snowfall, preciptotal, stnpressure, sealevel, resultspeed, resultdir, avgspeed]
# Index: []
#
# [0 rows x 23 columns]

# %%
few_comb2_df_tavg=few_comb2_df[few_comb2_df['tavg']=='M']
few_comb2_df_tavg.head()
# Out:
#             date  store_nbr  item_nbr  units  station_nbr tmax tmin tavg  \
# 4107  2012-01-01         39         1      0            8   66   45    M
# 4108  2012-01-01         39         2      0            8   66   45    M
# 4109  2012-01-01         39         3      0            8   66   45    M
# 4110  2012-01-01         39         4      0            8   66   45    M
# 4111  2012-01-01         39         5      0            8   66   45    M
#
#      depart dewpoint   ...    sunrise sunset codesum snowfall preciptotal  \
# 4107      M       34   ...          -      -   RA BR        M        0.00
# 4108      M       34   ...          -      -   RA BR        M        0.00
# 4109      M       34   ...          -      -   RA BR        M        0.00
# 4110      M       34   ...          -      -   RA BR        M        0.00
# 4111      M       34   ...          -      -   RA BR        M        0.00
#
#      stnpressure sealevel resultspeed resultdir avgspeed
# 4107       30.05        M        11.0        36     10.9
# 4108       30.05        M        11.0        36     10.9
# 4109       30.05        M        11.0        36     10.9
# 4110       30.05        M        11.0        36     10.9
# 4111       30.05        M        11.0        36     10.9
#
# [5 rows x 23 columns]

# %%
few_comb2_df_tavg=few_comb2_df[few_comb2_df['tavg']=='M']
few_comb2_df_tavg['tavg']=((few_comb2_df_tavg['tmax'].astype(int)+few_comb2_df_tavg['tmin'].astype(int))/2).astype(int)
few_comb2_df_tavg['tavg']
# Out:
# C:\Users\Anand\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 4107    55
# 4108    55
# 4109    55
# 4110    55
# 4111    55
# 4112    55
# 4113    55
# 4114    55
# 4115    55
# 4116    55
# 4117    55
# 4118    55
# 4119    55
# 4120    55
# 4121    55
# 4122    55
# 4123    55
# 4124    55
# 4125    55
# 4126    55
# 4127    55
# 4128    55
# 4129    55
# 4130    55
# 4131    55
# 4132    55
# 4133    55
# 4134    55
# 4135    55
# 4136    55
#         ..
# 9072    47
# 9073    47
# 9074    47
# 9075    47
# 9076    47
# 9077    47
# 9078    47
# 9079    47
# 9080    47
# 9081    47
# 9082    47
# 9083    47
# 9084    47
# 9085    47
# 9086    47
# 9087    47
# 9088    47
# 9089    47
# 9090    47
# 9091    47
# 9092    47
# 9093    47
# 9094    47
# 9095    47
# 9096    47
# 9097    47
# 9098    47
# 9099    47
# 9100    47
# 9101    47
# Name: tavg, Length: 222, dtype: int32

# %%
few_comb2_df_tavg['tavg'].fillna(few_comb2_df.groupby("tmax")["tmin"].transform("mean"), inplace=True)
few_comb2_df_tavg
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-75-9b2d6d848d75> in <module>()
#       1
#       2
# ----> 3 few_comb2_df_tavg['tavg'].fillna(few_comb2_df.groupby("tmax")["tmin"].transform("mean"), inplace=True)
#       4 few_comb2_df_tavg
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in transform(self, func, *args, **kwargs)
#    3033                 # cythonized aggregation and merge
#    3034                 return self._transform_fast(
# -> 3035                     lambda: getattr(self, func)(*args, **kwargs))
#    3036
#    3037         # reg transform
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in _transform_fast(self, func)
#    3074         ids, _, ngroup = self.grouper.group_info
#    3075         cast = (self.size().fillna(0) > 0).any()
# -> 3076         out = algorithms.take_1d(func().values, ids)
#    3077         if cast:
#    3078             out = self._try_cast(out, self.obj)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in <lambda>()
#    3033                 # cythonized aggregation and merge
#    3034                 return self._transform_fast(
# -> 3035                     lambda: getattr(self, func)(*args, **kwargs))
#    3036
#    3037         # reg transform
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in mean(self, *args, **kwargs)
#    1035         nv.validate_groupby_func('mean', args, kwargs, ['numeric_only'])
#    1036         try:
# -> 1037             return self._cython_agg_general('mean', **kwargs)
#    1038         except GroupByError:
#    1039             raise
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in _cython_agg_general(self, how, alt, numeric_only)
#     834
#     835         if len(output) == 0:
# --> 836             raise DataError('No numeric types to aggregate')
#     837
#     838         return self._wrap_aggregated_output(output, names)
#
# DataError: No numeric types to aggregate

# %%
few_comb2_df_na= few_comb2_df.replace('M', np.nan)
few_comb2_df_zero= few_comb2_df_na.fillna(few_comb2_df_na['depart'].mean)
few_comb2_df_zero.
# Out:
#          date  store_nbr  item_nbr  units  station_nbr tmax tmin tavg  \
# 0  2012-01-01          1         1      0            1   52   31   42
# 1  2012-01-01          1         2      0            1   52   31   42
# 2  2012-01-01          1         3      0            1   52   31   42
# 3  2012-01-01          1         4      0            1   52   31   42
# 4  2012-01-01          1         5      0            1   52   31   42
#
#                                               depart dewpoint   ...     \
# 0  <bound method Series.mean of 0      NaN\n1    ...       36   ...
# 1  <bound method Series.mean of 0      NaN\n1    ...       36   ...
# 2  <bound method Series.mean of 0      NaN\n1    ...       36   ...
# 3  <bound method Series.mean of 0      NaN\n1    ...       36   ...
# 4  <bound method Series.mean of 0      NaN\n1    ...       36   ...
#
#   sunrise sunset     codesum  \
# 0       -      -  RA FZFG BR
# 1       -      -  RA FZFG BR
# 2       -      -  RA FZFG BR
# 3       -      -  RA FZFG BR
# 4       -      -  RA FZFG BR
#
#                                             snowfall preciptotal stnpressure  \
# 0  <bound method Series.mean of 0      NaN\n1    ...        0.05       29.78
# 1  <bound method Series.mean of 0      NaN\n1    ...        0.05       29.78
# 2  <bound method Series.mean of 0      NaN\n1    ...        0.05       29.78
# 3  <bound method Series.mean of 0      NaN\n1    ...        0.05       29.78
# 4  <bound method Series.mean of 0      NaN\n1    ...        0.05       29.78
#
#   sealevel resultspeed resultdir avgspeed
# 0    29.92         3.6        20      4.6
# 1    29.92         3.6        20      4.6
# 2    29.92         3.6        20      4.6
# 3    29.92         3.6        20      4.6
# 4    29.92         3.6        20      4.6
#
# [5 rows x 23 columns]

# %%
few_comb2_df_zero.mean()
# Out:
# store_nbr       5.005
# item_nbr       55.945
# units           1.425
# station_nbr     9.336
# dtype: float64

# %%
df.loc[df['column_name'].isin(some_values)]

# %%
train_final_y_df = comb_2_df['units']
# print(len(train_final_y_df))
comb_2_df.drop = comb_2_df.drop(['station_nbr'], axis=1)
train_final_x_df = comb_2_df.drop('units', axis=1)
# print(train_final_x_df.info())
#lm.fit(train_final_x_df, train_final_y_df)
# print(lm.intercept_)
