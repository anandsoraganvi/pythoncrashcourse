# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x='tip',y='total_bill',data=tips)

# %%
sns.distplot(tips['total_bill'])

# %%
sns.distplot(tips['total_bill'],kde=False,bins=100)

# %%
sns.jointplot(x='total_bill',y='tip',data=tips)

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='kde')

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue='sex')

# %%
sns.rugplot(tips['total_bill'])

# %%
sns.distplot(tips['total_bill'],kde=False)

# %%
sns.pairplot(tips,hue='sex')

# %%
import numpy as np
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.var)

# %%
sns.countplot(x='sex',data=tips)

# %%
sns.boxplot(x='size',y='tip',data=tips,hue='smoker')

# %%
sns.violinplot(x='size',y='tip',data=tips,hue='smoker')

# %%
sns.violinplot(x='size',y='tip',data=tips,hue='smoker',split=True)

# %%
sns.stripplot(x='size',y='tip',data=tips,jitter=True,hue='sex',dodge=True)

# %%
sns.swarmplot(x='size',y='tip',data=tips)
sns.violinplot(x='size',y='tip',data=tips)

# %%
sns.factorplot(x='size',y='tip',data=tips,kind='bar')

# %%
flights=sns.load_dataset('flights')

# %%
flight.head(10)
# Out:
#    year      month  passengers
# 0  1949    January         112
# 1  1949   February         118
# 2  1949      March         132
# 3  1949      April         129
# 4  1949        May         121
# 5  1949       June         135
# 6  1949       July         148
# 7  1949     August         148
# 8  1949  September         136
# 9  1949    October         119

# %%
sns.distplot(flight['passengers'])

# %%
A=tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
B=flight.corr()

# %%
sns.heatmap(A)

# %%
sns.heatmap(B)

# %%
sns.heatmap(A,annot=True,cmap='coolwarm')

# %%
AF=flights.pivot_table(index='month',columns='year',values='passengers')

# %%
sns.heatmap(AF)

# %%
sns.heatmap(AF,cmap='magma',linewidth='0.5',linestyle='-')

# %%
sns.clustermap(AF,cmap='magma',linewidth='0.5',linecolor='w')

# %%
iris=sns.load_dataset('iris')
iris.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
sns.pairplot(iris)

# %%
g=sns.PairGrid(iris)
g.map_diag(sns.distplot)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)
# Out:
# C:\Users\Anand\Anaconda3\lib\site-packages\matplotlib\contour.py:967: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)

# %%
g=sns.FacetGrid(data=tips,col='time',row='smoker')
g.map(sns.distplot,'total_bill')

# %%
tips.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)

# %%
import pandas as pd
x=[2,6,16,27,45]
y=[7,9,17,67,78]
d=dict(zip(x,y))
df=pd.DataFrame(index=x,data=y,columns=['y'])
df.index.rename('x', inplace=True)
df
# Out:
#      y
# x
# 2    7
# 6    9
# 16  17
# 27  67
# 45  78

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',markers=['x','o'])

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex',row='time')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='day',hue='sex')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='day',hue='sex',aspect=0.5,size=8)

# %%
import numpy as np
sns.set_style('whitegrid')
sns.countplot(x='sex',data=tips)

# %%
sns.set_style('whitegrid')
sns.countplot(x='sex',data=tips)
sns.despine(bottom=True,left=True)
